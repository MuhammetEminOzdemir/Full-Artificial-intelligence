# %%
import pandas as pd
import numpy as np

# %%
from pandas import DataFrame,Series

# %%
seriler=Series(np.arange(6),index=['s1','s2','s3','s4','s5','s6'])

# %%
seriler
# Out:
# s1    0
# s2    1
# s3    2
# s4    3
# s5    4
# s6    5
# dtype: int32

# %%
seriler['s4']
# Out:
# 3

# %%
seriler[[0,5]]
# Out:
# s1    0
# s6    5
# dtype: int32

# %%
data=DataFrame(np.random.rand(6,6),
               index=['Mete','Ferhat','Batu','Ebru','Buğra','Rabiye'],
              columns=['Glukoz','Potasyum','Sodyum','ALT','CRP','Kandaki Oksijen'])

# %%
data.head() #ilk 5 veriyi verir head
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643  0.776585  0.993205  0.583592         0.760013
# Batu    0.515118  0.918062  0.801192  0.444750  0.338176         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356

# %%
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643  0.776585  0.993205  0.583592         0.760013
# Batu    0.515118  0.918062  0.801192  0.444750  0.338176         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data.Glukoz
# Out:
# Mete      0.873811
# Ferhat    0.301258
# Batu      0.515118
# Ebru      0.227878
# Buğra     0.285466
# Rabiye    0.088422
# Name: Glukoz, dtype: float64

# %%
data.loc[['Ferhat','Batu'],['Sodyum','CRP']] #satır sütün olduğu çift parantez kullanılır
# Out:
#           Sodyum       CRP
# Ferhat  0.776585  0.583592
# Batu    0.801192  0.338176

# %%
data < 0.5
# Out:
#         Glukoz  Potasyum  Sodyum    ALT    CRP  Kandaki Oksijen
# Mete     False      True    True  False  False            False
# Ferhat    True      True   False  False  False            False
# Batu     False     False   False   True   True             True
# Ebru      True     False    True  False   True            False
# Buğra     True     False   False   True  False             True
# Rabiye    True      True    True  False  False             True

# %%
data.loc[['Ferhat','Batu'],['Sodyum','CRP']]=np.nan   #eksik veri yapar

# %%
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
# bu derste eksik veri nasıl doldurulur eksik veri ile ilgili işlemler yapılacak...
#eksik verileri tamamlamak için kullanacağımız method !!!!!!
data.isnull().sum()  # serilerde kaç eksik veri var
# Out:
# Glukoz             0
# Potasyum           0
# Sodyum             2
# ALT                0
# CRP                2
# Kandaki Oksijen    0
# dtype: int64

# %%
data.isnull().sum().sum()  # toplam eksik veri sayısı verir
# Out:
# 4

# %%
data1=data.fillna(value=1) #nan olan dataları doldurma 1 ile doldur
data1
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643  1.000000  0.993205  1.000000         0.760013
# Batu    0.515118  0.918062  1.000000  0.444750  1.000000         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
# ama hala datamızda eksik veri vardır
data.isnull().sum().sum()
# Out:
# 4

# %%
data1=data.fillna(method='bfill')  #bfill kendinden sonraki datalara bakıyor 
data1
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643  0.079209  0.993205  0.037836         0.760013
# Batu    0.515118  0.918062  0.079209  0.444750  0.037836         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data1=data.fillna(method='ffill')  #ffill kendinden önceki datalara bakıyor 
data1
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643  0.218295  0.993205  0.619774         0.760013
# Batu    0.515118  0.918062  0.218295  0.444750  0.619774         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data2=DataFrame({'Hasta No' :[1,1,2,2,3,3,5],
                'Hastalık':['Grip','Grip','Covid','Covid','Zatürre','Zatürre','Zatürre'],
                'Yaş':[35,35,40,40,50,50,50]})
data2
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 1         1     Grip   35
# 2         2    Covid   40
# 3         2    Covid   40
# 4         3  Zatürre   50
# 5         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.drop_duplicates() # duplicate olan verileri yok et aynı verileri yok eder
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 2         2    Covid   40
# 4         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2  #yenidata2
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 1         1     Grip   35
# 2         2    Covid   40
# 3         2    Covid   40
# 4         3  Zatürre   50
# 5         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.duplicated()  #veri setimizdeki duplicates olan verileri gösterir
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
data2=data2.drop_duplicates()  #yenidata2
data2
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 2         2    Covid   40
# 4         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.drop_duplicates(['Hasta No']) #sadece o sütündaki yapıp gösterir
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 2         2    Covid   40
# 4         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.sort_values(by='Yaş') #değerleri sırala yaşa göre  by neye göre sıralanacağını gösterir
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 2         2    Covid   40
# 4         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data['Kandaki Oksijen']
# Out:
# Mete      0.580951
# Ferhat    0.760013
# Batu      0.087802
# Ebru      0.930288
# Buğra     0.410356
# Rabiye    0.258207
# Name: Kandaki Oksijen, dtype: float64

# %%
data.loc['Mete'] #metenin değerleri geldi
# Out:
# Glukoz             0.873811
# Potasyum           0.212399
# Sodyum             0.218295
# ALT                0.629204
# CRP                0.619774
# Kandaki Oksijen    0.580951
# Name: Mete, dtype: float64

# %%
data[['Sodyum',"CRP"]]
# Out:
#           Sodyum       CRP
# Mete    0.218295  0.619774
# Ferhat       NaN       NaN
# Batu         NaN       NaN
# Ebru    0.079209  0.037836
# Buğra   0.885460  0.846906
# Rabiye  0.054314  0.929709

# %%
data.columns
# Out:
# Index(['Glukoz', 'Potasyum', 'Sodyum', 'ALT', 'CRP', 'Kandaki Oksijen'], dtype='object')

# %%
data['Hepatit']=data['Sodyum'] + data['ALT']
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen  \
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207
#
#          Hepatit
# Mete    0.847499
# Ferhat       NaN
# Batu         NaN
# Ebru    0.968972
# Buğra   1.159318
# Rabiye  0.921908

# %%
data.drop(['Hepatit'],axis=1,inplace=True)
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data.loc[['Batu','Ebru'],['Sodyum','ALT']]
# Out:
#         Sodyum       ALT
# Batu       NaN  0.444750
# Ebru  0.079209  0.889764

# %%
filtre=data.ALT>data.ALT.mean()
data[filtre]
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207

# %%
data[data['Kandaki Oksijen']>data['Kandaki Oksijen'].mean()]
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288

# %%
data[(data['Kandaki Oksijen']>data['Kandaki Oksijen'].mean())&(data.Sodyum>0.5)]
# Out:
# Empty DataFrame
# Columns: [Glukoz, Potasyum, Sodyum, ALT, CRP, Kandaki Oksijen, index]
# Index: []

# %%
data['index']=[1000,1001,1002,1003,1004,1005]
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen  \
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209       NaN  0.037836              NaN
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314       NaN  0.929709              NaN
#
#         index
# Mete     1000
# Ferhat   1001
# Batu     1002
# Ebru     1003
# Buğra    1004
# Rabiye   1005

# %%
data.set_index('index')
# Out:
#          Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen
# index
# 1000   0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# 1001   0.301258  0.208643       NaN  0.993205       NaN         0.760013
# 1002   0.515118  0.918062       NaN  0.444750       NaN         0.087802
# 1003   0.227878  0.683392  0.079209       NaN  0.037836              NaN
# 1004   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# 1005   0.088422  0.062265  0.054314       NaN  0.929709              NaN

# %%
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen  \
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209  0.889764  0.037836         0.930288
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314  0.867594  0.929709         0.258207
#
#         index
# Mete     1000
# Ferhat   1001
# Batu     1002
# Ebru     1003
# Buğra    1004
# Rabiye   1005

# %%
data.loc[['Rabiye','Ebru'],['Kandaki Oksijen',"ALT"]]=np.nan
data
# Out:
#           Glukoz  Potasyum    Sodyum       ALT       CRP  Kandaki Oksijen  \
# Mete    0.873811  0.212399  0.218295  0.629204  0.619774         0.580951
# Ferhat  0.301258  0.208643       NaN  0.993205       NaN         0.760013
# Batu    0.515118  0.918062       NaN  0.444750       NaN         0.087802
# Ebru    0.227878  0.683392  0.079209       NaN  0.037836              NaN
# Buğra   0.285466  0.677506  0.885460  0.273858  0.846906         0.410356
# Rabiye  0.088422  0.062265  0.054314       NaN  0.929709              NaN
#
#         index
# Mete     1000
# Ferhat   1001
# Batu     1002
# Ebru     1003
# Buğra    1004
# Rabiye   1005

# %%
data.dropna(axis=1) #eksik veri olan bütün sütünü sildi.
# Out:
#           Glukoz  Potasyum  index
# Mete    0.873811  0.212399   1000
# Ferhat  0.301258  0.208643   1001
# Batu    0.515118  0.918062   1002
# Ebru    0.227878  0.683392   1003
# Buğra   0.285466  0.677506   1004
# Rabiye  0.088422  0.062265   1005
