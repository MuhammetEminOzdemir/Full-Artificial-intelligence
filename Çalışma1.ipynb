# %%
import numpy as np
import pandas as pd

# %%
#sınava yönelik çalışma
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
 'Capital': ['Brussels', 'New Delhi', 'Brasília'],
 'Population': [11190846, 1303171035, 207847528]}

df = pd.DataFrame(data,columns=['Country', 'Capital', 'Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
data={"isim":['Mete','Mustafa','çoşkun'],
     "Yaş":[35,14,86],
     "şehir":['erzurum','van','erçiş']}

data=pd.DataFrame(data)
data
# Out:
#       isim  Yaş    şehir
# 0     Mete   35  erzurum
# 1  Mustafa   14      van
# 2   çoşkun   86    erçiş

# %%
data['Yaş']
# Out:
# 0    35
# 1    14
# 2    86
# Name: Yaş, dtype: int64

# %%
data['Eğitim']=['lisans','ortaöğretim','lisans']
data
# Out:
#       isim  Yaş    şehir       Eğitim
# 0     Mete   35  erzurum       lisans
# 1  Mustafa   14      van  ortaöğretim
# 2   çoşkun   86    erçiş       lisans

# %%
data.loc[:,'Eğitim']
# Out:
# 0         lisans
# 1    ortaöğretim
# 2         lisans
# Name: Eğitim, dtype: object

# %%
data.loc[:1,'Eğitim']
# Out:
# 0         lisans
# 1    ortaöğretim
# Name: Eğitim, dtype: object

# %%
data
# Out:
#       isim  Yaş    şehir       Eğitim
# 0     Mete   35  erzurum       lisans
# 1  Mustafa   14      van  ortaöğretim
# 2   çoşkun   86    erçiş       lisans

# %%
data.loc[:,'isim':'şehir']
# Out:
#       isim  Yaş    şehir
# 0     Mete   35  erzurum
# 1  Mustafa   14      van
# 2   çoşkun   86    erçiş

# %%
data.loc[::-1]
# Out:
#       isim  Yaş    şehir       Eğitim
# 2   çoşkun   86    erçiş       lisans
# 1  Mustafa   14      van  ortaöğretim
# 0     Mete   35  erzurum       lisans

# %%
data.loc[::-1,:]
# Out:
#       isim  Yaş    şehir       Eğitim
# 2   çoşkun   86    erçiş       lisans
# 1  Mustafa   14      van  ortaöğretim
# 0     Mete   35  erzurum       lisans

# %%
data.loc[:,"isim"]
# Out:
# 0       Mete
# 1    Mustafa
# 2     çoşkun
# Name: isim, dtype: object

# %%
data.loc[:,:"isim"]
# Out:
#       isim
# 0     Mete
# 1  Mustafa
# 2   çoşkun

# %%
sozluk={"isim":['Mete','Ferhat','Batu','Ebru','Buğra','Emin'],
       "Yaş":[35,40,28,21,38,41],
       "CRP":[10,3,12,300,1,3]}

# %%
dataFrame = pd.DataFrame(sozluk)
dataFrame
# Out:
#      isim  Yaş  CRP
# 0    Mete   35   10
# 1  Ferhat   40    3
# 2    Batu   28   12
# 3    Ebru   21  300
# 4   Buğra   38    1
# 5    Emin   41    3

# %%
dataFrame['ALT']=[70,100,50,5,1,15]
dataFrame['Hastalık Durumu']=[1,1,0,1,0,1]
dataFrame
# Out:
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 0    Mete   35   10   70                1
# 1  Ferhat   40    3  100                1
# 2    Batu   28   12   50                0
# 3    Ebru   21  300    5                1
# 4   Buğra   38    1    1                0
# 5    Emin   41    3   15                1

# %%
dataFrame.describe()   #istatiksel değerlere döndürür
# Out:
#              Yaş         CRP         ALT  Hastalık Durumu
# count   6.000000    6.000000    6.000000         6.000000
# mean   33.833333   54.833333   40.166667         0.666667
# std     7.833688  120.185551   39.927017         0.516398
# min    21.000000    1.000000    1.000000         0.000000
# 25%    29.750000    3.000000    7.500000         0.250000
# 50%    36.500000    6.500000   32.500000         1.000000
# 75%    39.500000   11.500000   65.000000         1.000000
# max    41.000000  300.000000  100.000000         1.000000

# %%
dataFrame.Yaş>30
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# Name: Yaş, dtype: bool

# %%
filtre = dataFrame['Yaş']>35
filtre
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# Name: Yaş, dtype: bool

# %%
yeniData= dataFrame[filtre]
yeniData
# Out:
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 1  Ferhat   40    3  100                1
# 4   Buğra   38    1    1                0
# 5    Emin   41    3   15                1

# %%
filtre2=dataFrame.ALT>40
yeniData2=yeniData[filtre2]
yeniData2
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_4720\1203969029.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   yeniData2=yeniData[filtre2]
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 1  Ferhat   40    3  100                1

# %%
dataFrame
# Out:
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 0    Mete   35   10   70                1
# 1  Ferhat   40    3  100                1
# 2    Batu   28   12   50                0
# 3    Ebru   21  300    5                1
# 4   Buğra   38    1    1                0
# 5    Emin   41    3   15                1

# %%
filtre1=dataFrame.Yaş>dataFrame.Yaş.mean()
filtre2=dataFrame.CRP> dataFrame.CRP.mean()
yeniData= dataFrame[filtre1&filtre2]
yeniData
# Out:
# Empty DataFrame
# Columns: [isim, Yaş, CRP, ALT, Hastalık Durumu]
# Index: []

# %%
dataFrame.drop(['Hastalık Durumu'],axis=1)
# Out:
#      isim  Yaş  CRP  ALT
# 0    Mete   35   10   70
# 1  Ferhat   40    3  100
# 2    Batu   28   12   50
# 3    Ebru   21  300    5
# 4   Buğra   38    1    1
# 5    Emin   41    3   15

# %%
dataFrame  # drop kullandık fakat silmedi 2 yöntemi var bu kodu dataFrame atamamız lazım
# Out:
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 0    Mete   35   10   70                1
# 1  Ferhat   40    3  100                1
# 2    Batu   28   12   50                0
# 3    Ebru   21  300    5                1
# 4   Buğra   38    1    1                0
# 5    Emin   41    3   15                1

# %%
dataFrame
# Out:
#      isim  Yaş  CRP  ALT  Hastalık Durumu
# 0    Mete   35   10   70                1
# 1  Ferhat   40    3  100                1
# 2    Batu   28   12   50                0
# 3    Ebru   21  300    5                1
# 4   Buğra   38    1    1                0
# 5    Emin   41    3   15                1

# %%
dataFrame.drop(['ALT'],axis=1,inplace=True)

# %%
dataFrame
# Out:
#      isim  Yaş  CRP  Hastalık Durumu
# 0    Mete   35   10                1
# 1  Ferhat   40    3                1
# 2    Batu   28   12                0
# 3    Ebru   21  300                1
# 4   Buğra   38    1                0
# 5    Emin   41    3                1

# %%
ort=dataFrame.Yaş.mean()
ort
# Out:
# 33.833333333333336

# %%
dataFrame['Hastalık Durumu']=["Hasta" 
if ort<i 
else "Hasta Değil" 
for i in dataFrame.CRP]
dataFrame
# Out:
#      isim  Yaş  CRP Hastalık Durumu
# 0    Mete   35   10     Hasta Değil
# 1  Ferhat   40    3     Hasta Değil
# 2    Batu   28   12     Hasta Değil
# 3    Ebru   21  300           Hasta
# 4   Buğra   38    1     Hasta Değil
# 5    Emin   41    3     Hasta Değil

# %%
from pandas import DataFrame,Series

# %%
seriler=Series(np.arange(6),index=['s1','s2','s3','s4','s5','s6'])
seriler
# Out:
# s1    0
# s2    1
# s3    2
# s4    3
# s5    4
# s6    5
# dtype: int32

# %%
seriler[[0,5]]
# Out:
# s1    0
# s6    5
# dtype: int32

# %%
data=DataFrame(np.random.rand(5,5),
              index=['Mehmet','Akif','Mustafa','Emin','Şahin'],
              columns=['Glukoz','Potasyum','CRP','oksijen','ALT'])    
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873  0.434485  0.513460  0.332285
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797  0.771481  0.090123  0.559857
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data.head(3)
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873  0.434485  0.513460  0.332285
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023

# %%
data.loc[['Akif','Emin'],['CRP','ALT']] #satır sütün olduğu çift parantez kullanılır
# Out:
#            CRP       ALT
# Akif  0.434485  0.332285
# Emin  0.771481  0.559857

# %%
data.oksijen
# Out:
# Mehmet     0.051479
# Akif       0.513460
# Mustafa    0.491570
# Emin       0.090123
# Şahin      0.149336
# Name: oksijen, dtype: float64

# %%
data.loc[['Akif','Emin'],['CRP','ALT']]=np.nan
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873       NaN  0.513460       NaN
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797       NaN  0.090123       NaN
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data.isnull()
# Out:
#          Glukoz  Potasyum    CRP  oksijen    ALT
# Mehmet    False     False  False    False  False
# Akif      False     False   True    False   True
# Mustafa   False     False  False    False  False
# Emin      False     False   True    False   True
# Şahin     False     False  False    False  False

# %%
data.isnull().sum()
# Out:
# Glukoz      0
# Potasyum    0
# CRP         2
# oksijen     0
# ALT         2
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 4

# %%
data1=data.fillna(value=1) #nan olan dataları doldurma 1 ile doldur
data1
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873  1.000000  0.513460  1.000000
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797  1.000000  0.090123  1.000000
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
# ama hala datamızda eksik veri vardır
data.isnull().sum().sum()
# Out:
# 4

# %%
data1=data.fillna(method='bfill')  #bfill kendinden sonraki datalara bakıyor 
data1
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873  0.566145  0.513460  0.511023
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797  0.463481  0.090123  0.220710
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data1=data.fillna(method='ffill')  #ffill kendinden önceki datalara bakıyor 
data1
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873  0.950874  0.513460  0.401970
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797  0.566145  0.090123  0.511023
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data2=DataFrame({'Hasta No' :[1,1,2,2,3,3,5],
                'Hastalık':['Grip','Grip','Covid','Covid','Zatürre','Zatürre','Zatürre'],
                'Yaş':[35,35,40,40,50,50,50]})
data2
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 1         1     Grip   35
# 2         2    Covid   40
# 3         2    Covid   40
# 4         3  Zatürre   50
# 5         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.drop_duplicates()
# Out:
#    Hasta No Hastalık  Yaş
# 0         1     Grip   35
# 2         2    Covid   40
# 4         3  Zatürre   50
# 6         5  Zatürre   50

# %%
data2.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873       NaN  0.513460       NaN
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797       NaN  0.090123       NaN
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data['Hepatit']=data['Potasyum']+data['oksijen']  #oksijen ve potasyum değerlerini toplayrak yeni heptatit diye veri verir
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT   Hepatit
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970  0.675323
# Akif     0.523561  0.229873       NaN  0.513460       NaN  0.743333
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023  1.436660
# Emin     0.485267  0.243797       NaN  0.090123       NaN  0.333920
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710  0.499869

# %%
#sonra kaldıralım dasdadadsad
data.drop(['Hepatit'],axis=1,inplace=True)
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873       NaN  0.513460       NaN
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797       NaN  0.090123       NaN
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data.loc[['Akif','Şahin'],['Potasyum','ALT']]
# Out:
#        Potasyum      ALT
# Akif   0.229873      NaN
# Şahin  0.350533  0.22071

# %%
filtre=data.Potasyum>data.CRP.mean()   #data potasyum verileri data vrp verisinin ortalamsından büyük olanları getir
data[filtre]   #data filtre içerisine alıyoruz tablo olarak gelsin
# Out:
#           Glukoz  Potasyum       CRP  oksijen       ALT
# Mustafa  0.76456   0.94509  0.566145  0.49157  0.511023

# %%
data[data['oksijen']>data['oksijen'].mean()]
# Out:
#            Glukoz  Potasyum       CRP  oksijen       ALT
# Akif     0.523561  0.229873       NaN  0.51346       NaN
# Mustafa  0.764560  0.945090  0.566145  0.49157  0.511023

# %%
data[(data['oksijen']>data['oksijen'].mean())&(data.ALT>0.5)]
# Out:
#           Glukoz  Potasyum       CRP  oksijen       ALT
# Mustafa  0.76456   0.94509  0.566145  0.49157  0.511023

# %%
data['index']=[1000,1001,1002,1003,1004]
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT  index
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970   1000
# Akif     0.523561  0.229873       NaN  0.513460       NaN   1001
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023   1002
# Emin     0.485267  0.243797       NaN  0.090123       NaN   1003
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710   1004

# %%
data.set_index('index')  # sütünü başa alır
# Out:
#          Glukoz  Potasyum       CRP   oksijen       ALT
# index
# 1000   0.558980  0.623844  0.950874  0.051479  0.401970
# 1001   0.523561  0.229873       NaN  0.513460       NaN
# 1002   0.764560  0.945090  0.566145  0.491570  0.511023
# 1003   0.485267  0.243797       NaN  0.090123       NaN
# 1004   0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT  index
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970   1000
# Akif     0.523561  0.229873       NaN  0.513460       NaN   1001
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023   1002
# Emin     0.485267  0.243797       NaN  0.090123       NaN   1003
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710   1004

# %%
data.drop(['index'],axis=1,inplace=True)
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873       NaN  0.513460       NaN
# Mustafa  0.764560  0.945090  0.566145  0.491570  0.511023
# Emin     0.485267  0.243797       NaN  0.090123       NaN
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data.loc[['Mustafa','Emin'],['Glukoz','CRP']]=np.nan
data
# Out:
#            Glukoz  Potasyum       CRP   oksijen       ALT
# Mehmet   0.558980  0.623844  0.950874  0.051479  0.401970
# Akif     0.523561  0.229873       NaN  0.513460       NaN
# Mustafa       NaN  0.945090       NaN  0.491570  0.511023
# Emin          NaN  0.243797       NaN  0.090123       NaN
# Şahin    0.817566  0.350533  0.463481  0.149336  0.220710

# %%
data.dropna(axis=1)  #bütün sütünü siler nan olan
# Out:
#          Potasyum   oksijen
# Mehmet   0.623844  0.051479
# Akif     0.229873  0.513460
# Mustafa  0.945090  0.491570
# Emin     0.243797  0.090123
# Şahin    0.350533  0.149336

# %%
#-------------VERİ SETLERİ -----------
data=pd.read_csv("iris.csv")  #csv dosyası ile çalışma dosyan aynı yerde olmalı 
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
yeniData=data.drop(['Id'],axis=1)
yeniData
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
yeniData.shape
# Out:
# (150, 5)

# %%
yeniData.plot()
plt.show()

# %%
setosa=data[data.Species=='Iris-setosa']
versicolor=data[data.Species=='Iris-versicolor']
virginica=data[data.Species=='Iris-virginica']

# %%
setosa.plot()
plt.show()

# %%
setosa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.plot(setosa.Id,setosa.SepalWidthCm,color='blue')
plt.xlabel('Id') #x eksinene yazılacak yazı
plt.ylabel('Sepal Width Cm') #y eksinene yazılacak yazı
plt.title('Setosa Görselleştirme')
plt.show()

# %%
plt.plot(setosa.Id,setosa.SepalLengthCm,color='b',label='setosa görseli',linestyle='-.')  #setosa sınıf gösterimi
plt.plot(versicolor.Id,versicolor.SepalLengthCm,color='r',label='versicolor görseli',linestyle='-.')#versicolor sınıf gösterimi
plt.plot(virginica.Id,virginica.SepalLengthCm,color='g',label='virginica görseli',linestyle='-.')
plt.legend()  #label yazılarının görselde gösterimi için yazılır
plt.xlabel('Id')
plt.ylabel('Sepal Length Cm')
plt.title('Sınıfların Sepal Length Cm e göre dağılımı')
plt.show()

# %%
plt.hist(versicolor.PetalLengthCm,bins=20,color='g') #histogramını çizdirir
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(setosa.Id,setosa.PetalLengthCm,color='b',label='setosa')
plt.legend()

plt.subplot(2,1,2)
plt.plot(virginica.Id,virginica.PetalLengthCm,color='r',label='virginica')
plt.legend()
    
plt.show()

# %%
filtre1=data.SepalLengthCm>data.SepalWidthCm.mean()
filtre2=data.PetalLengthCm>data.PetalWidthCm.mean()
filtrelenmisData=data[filtre1&filtre2]
filtrelenmisData.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.groupby("Species").size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
#seaborn python da kullanılan veri görselliştirmedir
import seaborn as sns #seaborn kütüphanemize dahil edelim

# %%
sns.countplot("Species",data=data)   # görselleştirme yapar countplot sns seaborn   cokkkkk önemlii çıkar
                     #kütüphanesinin sınıf verimizin datamıza göre dağılımını sayısal olarak karşılığını verir
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
#bir diğer grafiğimiz adıda  pie plot
import matplotlib.pyplot as plt  #import edelim
data["Species"].value_counts().plot.pie(autopct='%.2f')   #species sınıfını verilerini dağılımını yapalım
plt.show()

# %%
sns.catplot(data=data, x="SepalLengthCm", y="Species", kind="box")
plt.show()

# %%
sns.catplot(data=data, x="SepalLengthCm", y="Species", kind="bar")
plt.show()

# %%
sns.catplot(data=data, x="SepalLengthCm", y="Species")
plt.show()

# %%
#heatmap hata matris için kullanırız grafikler buda veri görselliştirmedir.
korelasyon=data1.corr()  #korelasyonu bulmayı corr 
korelasyon
# Out:
#             Glukoz  Potasyum       CRP   oksijen       ALT
# Glukoz    1.000000  0.484114 -0.623232  0.168497 -0.491238
# Potasyum  0.484114  1.000000 -0.093762  0.250506  0.334731
# CRP      -0.623232 -0.093762  1.000000  0.139050  0.123640
# oksijen   0.168497  0.250506  0.139050  1.000000  0.251029
# ALT      -0.491238  0.334731  0.123640  0.251029  1.000000

# %%
sns.heatmap(korelasyon,annot=True)  #annot yazı yazmasını sağlar
plt.show()

# %%
# bir kategorik verileri sayılaştırma ve eksik verilerle ilgili işlemler
veri=pd.read_csv("eksikveriler.csv")
veri.head()
# Out:
#   eegkanal  frekans  glukoz   yas hasta
# 0    F3-C3       13      70  40.0     e
# 1    F3-C3       12      36  41.0     e
# 2    F3-C3        6      88  60.0     h
# 3    F3-C3        8      98  54.0     h
# 4    F3-C3       11      70  52.0     e

# %%
veri.hasta.value_counts()  #11 kişi hasta 9 kişi hasta değil bu veri setinde
# Out:
# e    11
# h     9
# Name: hasta, dtype: int64

# %%
veri.isnull().sum()
# Out:
# eegkanal    0
# frekans     0
# glukoz      0
# yas         3
# hasta       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

veri.hasta=le.fit_transform(veri.hasta)   #label encoder methodu kategroik verileri sayılaşştırır e h--- 0,1 oldu
veri
# Out:
#    eegkanal  frekans  glukoz   yas  hasta
# 0     F3-C3       13      70  40.0      0
# 1     F3-C3       12      36  41.0      0
# 2     F3-C3        6      88  60.0      1
# 3     F3-C3        8      98  54.0      1
# 4     F3-C3       11      70  52.0      0
# 5     F3-C3       11      90  30.0      0
# 6     F3-C3        8      80  25.0      0
# 7     F3-C3        6      95  43.0      0
# 8     F3-C3        8      90  47.0      1
# 9     F4-C4        8     125  69.0      0
# 10    F4-C4        8      87  40.0      1
# 11    F4-C4        9      86  37.0      1
# 12    F4-C4        5      78  50.0      1
# 13    F4-C4       11      88   NaN      1
# 14    F4-C4       10      79  60.0      1
# 15    T4-T6        5      67   NaN      0
# 16    T4-T6       11      69   NaN      0
# 17    T4-T6       10      90  45.0      0
# 18    T4-T6        7      70  46.0      0
# 19    T4-T6        8      60  45.0      1

# %%
veri=pd.read_csv("eksikveriler.csv")
from sklearn.impute import SimpleImputer
eksikveriTamamlama=SimpleImputer(missing_values=np.nan, strategy='mean')
eksikveriTamamlama.fit(veri.iloc[:,1:4])
veri.iloc[:,1:4]=eksikveriTamamlama.transform(veri.iloc[:,1:4])
veri
# Out:
#    eegkanal  frekans  glukoz        yas hasta
# 0     F3-C3     13.0    70.0  40.000000     e
# 1     F3-C3     12.0    36.0  41.000000     e
# 2     F3-C3      6.0    88.0  60.000000     h
# 3     F3-C3      8.0    98.0  54.000000     h
# 4     F3-C3     11.0    70.0  52.000000     e
# 5     F3-C3     11.0    90.0  30.000000     e
# 6     F3-C3      8.0    80.0  25.000000     e
# 7     F3-C3      6.0    95.0  43.000000     e
# 8     F3-C3      8.0    90.0  47.000000     h
# 9     F4-C4      8.0   125.0  69.000000     e
# 10    F4-C4      8.0    87.0  40.000000     h
# 11    F4-C4      9.0    86.0  37.000000     h
# 12    F4-C4      5.0    78.0  50.000000     h
# 13    F4-C4     11.0    88.0  46.117647     h
# 14    F4-C4     10.0    79.0  60.000000     h
# 15    T4-T6      5.0    67.0  46.117647     e
# 16    T4-T6     11.0    69.0  46.117647     e
# 17    T4-T6     10.0    90.0  45.000000     e
# 18    T4-T6      7.0    70.0  46.000000     e
# ...

# %%
veri.eegkanal.value_counts()
# Out:
# F3-C3    9
# F4-C4    6
# T4-T6    5
# Name: eegkanal, dtype: int64

# %%
veri
# Out:
#    eegkanal  frekans  glukoz        yas hasta
# 0     F3-C3     13.0    70.0  40.000000     e
# 1     F3-C3     12.0    36.0  41.000000     e
# 2     F3-C3      6.0    88.0  60.000000     h
# 3     F3-C3      8.0    98.0  54.000000     h
# 4     F3-C3     11.0    70.0  52.000000     e
# 5     F3-C3     11.0    90.0  30.000000     e
# 6     F3-C3      8.0    80.0  25.000000     e
# 7     F3-C3      6.0    95.0  43.000000     e
# 8     F3-C3      8.0    90.0  47.000000     h
# 9     F4-C4      8.0   125.0  69.000000     e
# 10    F4-C4      8.0    87.0  40.000000     h
# 11    F4-C4      9.0    86.0  37.000000     h
# 12    F4-C4      5.0    78.0  50.000000     h
# 13    F4-C4     11.0    88.0  46.117647     h
# 14    F4-C4     10.0    79.0  60.000000     h
# 15    T4-T6      5.0    67.0  46.117647     e
# 16    T4-T6     11.0    69.0  46.117647     e
# 17    T4-T6     10.0    90.0  45.000000     e
# 18    T4-T6      7.0    70.0  46.000000     e
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
sklearn.preprocessing.OneHotEncoder(*, categories='auto', drop=None, sparse=True
